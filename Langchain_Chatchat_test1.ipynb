# %% [markdown]
# ## 环境检测 Python 3.8 - 3.10

# %%
# pip install --upgrade openai
# !python --version
# Out:
# Python 3.10.12

# %% [markdown]
# ##仓库拉取 依赖安装

# %%
# !git clone https://github.com/chatchat-space/Langchain-Chatchat.git
# Out:
# Cloning into 'Langchain-Chatchat'...
# remote: Enumerating objects: 12693, done.
# remote: Counting objects: 100% (3187/3187), done.
# remote: Compressing objects: 100% (2257/2257), done.
# remote: Total 12693 (delta 925), reused 2972 (delta 820), pack-reused 9506
# Receiving objects: 100% (12693/12693), 82.25 MiB | 18.65 MiB/s, done.
# Resolving deltas: 100% (6733/6733), done.

# %%
repo_dir = "/content/Langchain-Chatchat"
# %cd $repo_dir
# Out:
# /content/Langchain-Chatchat

# %%
# 安装全部依赖
# !pip install -r requirements.txt
# !pip install -r requirements_api.txt
# !pip install -r requirements_webui.txt
# 默认依赖包括基本运行环境（FAISS向量库）。如果要使用 milvus/pg_vector 等向量库，请将 requirements.txt 中相应依赖取消注释再安装。

# %% [markdown]
# ## 模型下载

# %%
# !git lfs install
# Out:
# Updated git hooks.
# Git LFS initialized.

# %%
# !rm -r chatglm3-6b
# !git clone https://huggingface.co/THUDM/chatglm3-6b

# 需要修改配置文件
# !rm -r Qwen-1_8B-Chat
# !git clone https://huggingface.co/Qwen/Qwen-1_8B-Chat
# Out:
# rm: cannot remove 'Qwen-1_8B-Chat': No such file or directory
# Cloning into 'Qwen-1_8B-Chat'...
# remote: Enumerating objects: 58, done.
# remote: Total 58 (delta 0), reused 0 (delta 0), pack-reused 58
# Unpacking objects: 100% (58/58), 2.59 MiB | 7.88 MiB/s, done.
# Filtering content: 100% (2/2), 3.42 GiB | 51.39 MiB/s, done.

# %%
# !rm -r bge-large-zh
# !git clone https://huggingface.co/BAAI/bge-large-zh
# Out:
# rm: cannot remove 'bge-large-zh': No such file or directory
# Cloning into 'bge-large-zh'...
# remote: Enumerating objects: 70, done.
# remote: Total 70 (delta 0), reused 0 (delta 0), pack-reused 70
# Unpacking objects: 100% (70/70), 177.62 KiB | 3.78 MiB/s, done.
# Filtering content: 100% (2/2), 2.42 GiB | 44.65 MiB/s, done.

# %% [markdown]
# ## 初始化知识库和配置文件

# %%
# 删除多余的知识库文件
# !rm -R /content/Langchain-Chatchat/knowledge_base/samples/content/
# !mkdir /content/Langchain-Chatchat/knowledge_base/samples/content/

# %%
# 初始化配置
# !python copy_config_example.py

# %%
# 初始化知识库
# !python init_database.py --recreate-vs
# Out:
# recreating all vector stores
# 2024-03-22 02:35:53,232 - faiss_cache.py[line:92] - INFO: loading vector store in 'samples/vector_store/bge-large-zh-v1.5' from disk.
# 2024-03-22 02:35:55,504 - SentenceTransformer.py[line:66] - INFO: Load pretrained SentenceTransformer: BAAI/bge-large-zh-v1.5
# .gitattributes: 100% 1.52k/1.52k [00:00<00:00, 7.48MB/s]
# 1_Pooling/config.json: 100% 191/191 [00:00<00:00, 926kB/s]
# README.md: 100% 30.3k/30.3k [00:00<00:00, 8.99MB/s]
# config.json: 100% 1.00k/1.00k [00:00<00:00, 4.04MB/s]
# config_sentence_transformers.json: 100% 124/124 [00:00<00:00, 615kB/s]
# model.safetensors: 100% 1.30G/1.30G [00:13<00:00, 95.5MB/s]
# pytorch_model.bin: 100% 1.30G/1.30G [00:45<00:00, 28.6MB/s]
# sentence_bert_config.json: 100% 52.0/52.0 [00:00<00:00, 249kB/s]
# special_tokens_map.json: 100% 125/125 [00:00<00:00, 526kB/s]
# tokenizer.json: 100% 439k/439k [00:00<00:00, 7.08MB/s]
# tokenizer_config.json: 100% 394/394 [00:00<00:00, 2.06MB/s]
# vocab.txt: 100% 110k/110k [00:00<00:00, 2.08MB/s]
# modules.json: 100% 349/349 [00:00<00:00, 1.77MB/s]
# Batches: 100% 1/1 [00:01<00:00,  1.05s/it]
# 2024-03-22 02:37:01,561 - loader.py[line:54] - INFO: Loading faiss with AVX2 support.
# 2024-03-22 02:37:01,653 - loader.py[line:56] - INFO: Successfully loaded faiss with AVX2 support.
# /usr/local/lib/python3.10/dist-packages/langchain_community/vectorstores/faiss.py:121: UserWarning: Normalizing L2 is not applicable for metric type: METRIC_INNER_PRODUCT
#   warnings.warn(
# 2024-03-22 02:37:01,711 - faiss_cache.py[line:92] - INFO: loading vector store in 'samples/vector_store/bge-large-zh-v1.5' from disk.
# Batches: 100% 1/1 [00:00<00:00, 33.06it/s]
# 2024-03-22 02:37:01,752 - faiss_cache.py[line:38] - INFO: 已将向量库 ('samples', 'bge-large-zh-v1.5') 保存到磁盘
# 总计用时： 0:01:08.724606

# %% [markdown]
# ## 内网穿透

# %%
# !npm install -g localtunnel
# Out:
# /tools/node/bin/lt -> /tools/node/lib/node_modules/localtunnel/bin/lt.js
# + localtunnel@2.0.2
# added 22 packages from 22 contributors in 2.052s

# %%
# !curl ipv4.icanhazip.com
# Out:
# 34.138.223.25

# %% [markdown]
# ## 启动

# %%
# !python ./startup.py -a & lt --port 8501 --subdomain wangzongming
# Out:
# your url is: https://wangzongming.loca.lt
#
#
# ==============================Langchain-Chatchat Configuration==============================
# 操作系统：Linux-6.1.58+-x86_64-with-glibc2.35.
# python版本：3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# 项目版本：v0.2.10
# langchain版本：0.0.354. fastchat版本：0.2.35
#
#
# 当前使用的分词器：ChineseRecursiveTextSplitter
# 当前启动的LLM模型：['qwen-api', 'Qwen-1_8B-Chat', 'openai-api'] @ cuda
# {'api_key': 'sk-2a9afd13184c4b239739f25b370f8d21',
#  'device': 'auto',
#  'embed_model': 'text-embedding-v1',
#  'host': '0.0.0.0',
#  'infer_turbo': False,
#  'online_api': True,
#  'port': 21006,
#  'provider': 'QwenWorker',
#  'version': 'qwen-turbo',
#  'worker_class': <class 'server.model_workers.qwen.QwenWorker'>}
# {'device': 'cuda',
#  'host': '0.0.0.0',
#  'infer_turbo': False,
#  'model_path': 'Qwen-1_8B-Chat',
#  'model_path_exists': True,
#  'port': 20002}
# {'api_base_url': 'https://api.openai.com/v1',
#  'api_key': '',
#  'device': 'auto',
#  'host': '0.0.0.0',
#  'infer_turbo': False,
#  'model_name': 'gpt-4',
#  'online_api': True,
#  'openai_proxy': '',
#  'port': 20002}
# 当前Embbedings模型： bge-large-zh-v1.5 @ cuda
# ==============================Langchain-Chatchat Configuration==============================
#
#
# 2024-03-22 03:50:48,832 - startup.py[line:655] - INFO: 正在启动服务：
# 2024-03-22 03:50:48,832 - startup.py[line:656] - INFO: 如需查看 llm_api 日志，请前往 /content/Langchain-Chatchat/logs
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: 模型启动功能将于 Langchain-Chatchat 0.3.x重写,支持更多模式和加速启动，0.2.x中相关功能将废弃
#   warn_deprecated(
# 2024-03-22 03:51:02 | ERROR | stderr | INFO:     Started server process [22505]
# 2024-03-22 03:51:02 | ERROR | stderr | INFO:     Waiting for application startup.
# 2024-03-22 03:51:02 | ERROR | stderr | INFO:     Application startup complete.
# 2024-03-22 03:51:02 | ERROR | stderr | INFO:     Uvicorn running on http://0.0.0.0:20000 (Press CTRL+C to quit)
# 2024-03-22 03:51:02 | INFO | model_worker | Register to controller
# 2024-03-22 03:51:03 | INFO | model_worker | Loading the model ['Qwen-1_8B-Chat'] on worker 06cd02f7 ...
# 2024-03-22 03:51:03 | WARNING | transformers_modules.Qwen-1_8B-Chat.modeling_qwen | Try importing flash-attention for faster inference...
# 2024-03-22 03:51:03 | WARNING | transformers_modules.Qwen-1_8B-Chat.modeling_qwen | Warning: import flash_attn rotary fail, please install FlashAttention rotary to get higher efficiency https://github.com/Dao-AILab/flash-attention/tree/main/csrc/rotary
# 2024-03-22 03:51:03 | WARNING | transformers_modules.Qwen-1_8B-Chat.modeling_qwen | Warning: import flash_attn rms_norm fail, please install FlashAttention layer_norm to get higher efficiency https://github.com/Dao-AILab/flash-attention/tree/main/csrc/layer_norm
# 2024-03-22 03:51:03 | WARNING | transformers_modules.Qwen-1_8B-Chat.modeling_qwen | Warning: import flash_attn fail, please install FlashAttention to get higher efficiency https://github.com/Dao-AILab/flash-attention
# Loading checkpoint shards:   0% 0/2 [00:00<?, ?it/s]
# Loading checkpoint shards:  50% 1/2 [00:12<00:12, 12.84s/it]
# Loading checkpoint shards: 100% 2/2 [00:20<00:00,  9.92s/it]
# Loading checkpoint shards: 100% 2/2 [00:20<00:00, 10.36s/it]
# 2024-03-22 03:51:24 | ERROR | stderr |
# 2024-03-22 03:51:27 | INFO | model_worker | Register to controller
# INFO:     Started server process [22687]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:7861 (Press CTRL+C to quit)
#
#
# ==============================Langchain-Chatchat Configuration==============================
# 操作系统：Linux-6.1.58+-x86_64-with-glibc2.35.
# python版本：3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# 项目版本：v0.2.10
# langchain版本：0.0.354. fastchat版本：0.2.35
#
#
# 当前使用的分词器：ChineseRecursiveTextSplitter
# 当前启动的LLM模型：['qwen-api', 'Qwen-1_8B-Chat', 'openai-api'] @ cuda
# {'api_key': 'sk-2a9afd13184c4b239739f25b370f8d21',
#  'device': 'auto',
#  'embed_model': 'text-embedding-v1',
#  'host': '0.0.0.0',
#  'infer_turbo': False,
#  'online_api': True,
#  'port': 21006,
#  'provider': 'QwenWorker',
#  'version': 'qwen-turbo',
#  'worker_class': <class 'server.model_workers.qwen.QwenWorker'>}
# {'device': 'cuda',
#  'host': '0.0.0.0',
#  'infer_turbo': False,
#  'model_path': 'Qwen-1_8B-Chat',
#  'model_path_exists': True,
#  'port': 20002}
# {'api_base_url': 'https://api.openai.com/v1',
#  'api_key': '',
#  'device': 'auto',
#  'host': '0.0.0.0',
#  'infer_turbo': False,
#  'model_name': 'gpt-4',
#  'online_api': True,
#  'openai_proxy': '',
#  'port': 20002}
# 当前Embbedings模型： bge-large-zh-v1.5 @ cuda
#
#
# 服务端运行信息：
#     OpenAI API Server: http://127.0.0.1:20000/v1
#     Chatchat  API  Server: http://127.0.0.1:7861
#     Chatchat WEBUI Server: http://0.0.0.0:8501
# ==============================Langchain-Chatchat Configuration==============================
#
#
#
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to False.
#
#
#   You can now view your Streamlit app in your browser.
#
#   URL: http://0.0.0.0:8501
#
#
#   A new version of Streamlit is available.
#
#   See what's new at https://discuss.streamlit.io/c/announcements
#
#   Enter the following command to upgrade:
#   $ pip install streamlit --upgrade
#
# 2024-03-22 03:51:53,004 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# 2024-03-22 03:51:53,005 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:55466 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55468 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 03:51:53,009 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# 2024-03-22 03:51:53,011 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# 2024-03-22 03:51:53,213 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# 2024-03-22 03:51:53,216 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:55466 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 03:51:53,218 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:55468 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 03:51:53,220 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:55466 - "POST /llm_model/list_config_models HTTP/1.1" 200 OK
# 2024-03-22 03:51:53,241 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_config_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:55468 - "POST /llm_model/list_config_models HTTP/1.1" 200 OK
# 2024-03-22 03:51:53,252 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_config_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:55466 - "GET /knowledge_base/list_knowledge_bases HTTP/1.1" 200 OK
# 2024-03-22 03:51:53,476 - _client.py[line:1027] - INFO: HTTP Request: GET http://127.0.0.1:7861/knowledge_base/list_knowledge_bases "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:57338 - "POST /llm_model/get_model_config HTTP/1.1" 200 OK
# 2024-03-22 03:52:02,509 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/get_model_config "HTTP/1.1 200 OK"
# 2024-03-22 03:52:02,733 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:57354 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 03:52:02,735 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# 2024-03-22 03:52:02,791 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:57354 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 03:52:02,793 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:57354 - "POST /llm_model/list_config_models HTTP/1.1" 200 OK
# 2024-03-22 03:52:02,804 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_config_models "HTTP/1.1 200 OK"
# 2024-03-22 03:52:05,562 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:47146 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 03:52:05,565 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# 2024-03-22 03:52:05,621 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:47146 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 03:52:05,623 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:47146 - "POST /llm_model/list_config_models HTTP/1.1" 200 OK
# 2024-03-22 03:52:05,638 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_config_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:47146 - "POST /chat/chat HTTP/1.1" 200 OK
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.chat_models.openai.ChatOpenAI` was deprecated in langchain-community 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   warn_deprecated(
# 2024-03-22 03:52:05,821 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/chat/chat "HTTP/1.1 200 OK"
# 2024-03-22 03:52:05 | INFO | stdout | INFO:     127.0.0.1:59900 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# 2024-03-22 03:52:05,957 - _client.py[line:1758] - INFO: HTTP Request: POST http://127.0.0.1:20000/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-03-22 03:52:05 | INFO | httpx | HTTP Request: POST http://127.0.0.1:21006/worker_generate_stream "HTTP/1.1 200 OK"
# 2024-03-22 03:52:05,968 - utils.py[line:38] - ERROR: object of type 'NoneType' has no len()
# Traceback (most recent call last):
#   File "/content/Langchain-Chatchat/server/utils.py", line 36, in wrap_done
#     await fn
#   File "/usr/local/lib/python3.10/dist-packages/langchain/chains/base.py", line 385, in acall
#     raise e
#   File "/usr/local/lib/python3.10/dist-packages/langchain/chains/base.py", line 379, in acall
#     await self._acall(inputs, run_manager=run_manager)
#   File "/usr/local/lib/python3.10/dist-packages/langchain/chains/llm.py", line 275, in _acall
#     response = await self.agenerate([inputs], run_manager=run_manager)
#   File "/usr/local/lib/python3.10/dist-packages/langchain/chains/llm.py", line 142, in agenerate
#     return await self.llm.agenerate_prompt(
#   File "/usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py", line 554, in agenerate_prompt
#     return await self.agenerate(
#   File "/usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py", line 514, in agenerate
#     raise exceptions[0]
#   File "/usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py", line 617, in _agenerate_with_cache
#     return await self._agenerate(
#   File "/usr/local/lib/python3.10/dist-packages/langchain_community/chat_models/openai.py", line 522, in _agenerate
#     return await agenerate_from_stream(stream_iter)
#   File "/usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py", line 87, in agenerate_from_stream
#     async for chunk in stream:
#   File "/usr/local/lib/python3.10/dist-packages/langchain_community/chat_models/openai.py", line 493, in _astream
#     if len(chunk["choices"]) == 0:
# TypeError: object of type 'NoneType' has no len()
# 2024-03-22 03:52:05,976 - utils.py[line:40] - ERROR: TypeError: Caught exception: object of type 'NoneType' has no len()
# 2024-03-22 03:52:28,368 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:41080 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 03:52:28,372 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# 2024-03-22 03:52:28,433 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:41080 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 03:52:28,435 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:41080 - "POST /llm_model/list_config_models HTTP/1.1" 200 OK
# 2024-03-22 03:52:28,446 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_config_models "HTTP/1.1 200 OK"
# 2024-03-22 03:52:38,763 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:36190 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 03:52:38,766 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# 2024-03-22 03:52:38,825 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:36190 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 03:52:38,828 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:36190 - "POST /llm_model/list_config_models HTTP/1.1" 200 OK
# 2024-03-22 03:52:38,839 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_config_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:36190 - "POST /chat/chat HTTP/1.1" 200 OK
# 2024-03-22 03:52:38,989 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/chat/chat "HTTP/1.1 200 OK"
# 2024-03-22 03:52:39 | INFO | stdout | INFO:     127.0.0.1:58534 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# 2024-03-22 03:52:39,074 - _client.py[line:1758] - INFO: HTTP Request: POST http://127.0.0.1:20000/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-03-22 03:52:39 | INFO | httpx | HTTP Request: POST http://127.0.0.1:21006/worker_generate_stream "HTTP/1.1 200 OK"
# 2024-03-22 03:52:39,079 - utils.py[line:38] - ERROR: object of type 'NoneType' has no len()
# Traceback (most recent call last):
#   File "/content/Langchain-Chatchat/server/utils.py", line 36, in wrap_done
#     await fn
#   File "/usr/local/lib/python3.10/dist-packages/langchain/chains/base.py", line 385, in acall
#     raise e
#   File "/usr/local/lib/python3.10/dist-packages/langchain/chains/base.py", line 379, in acall
#     await self._acall(inputs, run_manager=run_manager)
#   File "/usr/local/lib/python3.10/dist-packages/langchain/chains/llm.py", line 275, in _acall
#     response = await self.agenerate([inputs], run_manager=run_manager)
#   File "/usr/local/lib/python3.10/dist-packages/langchain/chains/llm.py", line 142, in agenerate
#     return await self.llm.agenerate_prompt(
#   File "/usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py", line 554, in agenerate_prompt
#     return await self.agenerate(
#   File "/usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py", line 514, in agenerate
#     raise exceptions[0]
#   File "/usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py", line 617, in _agenerate_with_cache
#     return await self._agenerate(
#   File "/usr/local/lib/python3.10/dist-packages/langchain_community/chat_models/openai.py", line 522, in _agenerate
#     return await agenerate_from_stream(stream_iter)
#   File "/usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py", line 87, in agenerate_from_stream
#     async for chunk in stream:
#   File "/usr/local/lib/python3.10/dist-packages/langchain_community/chat_models/openai.py", line 493, in _astream
#     if len(chunk["choices"]) == 0:
# TypeError: object of type 'NoneType' has no len()
# 2024-03-22 03:52:39,080 - utils.py[line:40] - ERROR: TypeError: Caught exception: object of type 'NoneType' has no len()
# 2024-03-22 03:52:39.082 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 535, in _run_script
#     exec(code, module.__dict__)
#   File "/content/Langchain-Chatchat/webui.py", line 64, in <module>
#     pages[selected_page]["func"](api=api, is_lite=is_lite)
#   File "/content/Langchain-Chatchat/webui_pages/dialogue/dialogue.py", line 324, in dialogue_page
#     chat_box.show_feedback(**feedback_kwargs,
#   File "/usr/local/lib/python3.10/dist-packages/streamlit_chatbox/messages.py", line 309, in show_feedback
#     return streamlit_feedback(**kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/streamlit_feedback/__init__.py", line 104, in streamlit_feedback
#     component_value = _component_func(
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/components/v1/components.py", line 80, in __call__
#     return self.create_instance(*args, default=default, key=key, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/metrics_util.py", line 396, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/components/v1/components.py", line 241, in create_instance
#     return_value = marshall_component(dg, element)
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/components/v1/components.py", line 212, in marshall_component
#     component_state = register_widget(
#   File "/usr/local/lib/python3.10/dist-packages/streamlit_option_menu/streamlit_callback.py", line 20, in wrapper_register_widget
#     return register_widget(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/state/widgets.py", line 161, in register_widget
#     return register_widget_from_metadata(metadata, ctx, widget_func_name, element_type)
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/state/widgets.py", line 194, in register_widget_from_metadata
#     raise DuplicateWidgetID(
# streamlit.errors.DuplicateWidgetID: There are multiple widgets with the same `key=''`.
#
# To fix this, please make sure that the `key` argument is unique for each
# widget you create.
# 2024-03-22 03:54:41,251 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:54996 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 03:54:41,254 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# 2024-03-22 03:54:41,314 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:54996 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 03:54:41,316 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:54996 - "POST /llm_model/list_config_models HTTP/1.1" 200 OK
# 2024-03-22 03:54:41,328 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_config_models "HTTP/1.1 200 OK"
# 2024-03-22 03:54:41.341 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 535, in _run_script
#     exec(code, module.__dict__)
#   File "/content/Langchain-Chatchat/webui.py", line 64, in <module>
#     pages[selected_page]["func"](api=api, is_lite=is_lite)
#   File "/content/Langchain-Chatchat/webui_pages/dialogue/dialogue.py", line 275, in dialogue_page
#     chat_box.output_messages()
#   File "/usr/local/lib/python3.10/dist-packages/streamlit_chatbox/messages.py", line 337, in output_messages
#     self.show_feedback(history_index=i, **feedback_kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/streamlit_chatbox/messages.py", line 309, in show_feedback
#     return streamlit_feedback(**kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/streamlit_feedback/__init__.py", line 104, in streamlit_feedback
#     component_value = _component_func(
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/components/v1/components.py", line 80, in __call__
#     return self.create_instance(*args, default=default, key=key, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/metrics_util.py", line 396, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/components/v1/components.py", line 241, in create_instance
#     return_value = marshall_component(dg, element)
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/components/v1/components.py", line 212, in marshall_component
#     component_state = register_widget(
#   File "/usr/local/lib/python3.10/dist-packages/streamlit_option_menu/streamlit_callback.py", line 20, in wrapper_register_widget
#     return register_widget(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/state/widgets.py", line 161, in register_widget
#     return register_widget_from_metadata(metadata, ctx, widget_func_name, element_type)
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/state/widgets.py", line 194, in register_widget_from_metadata
#     raise DuplicateWidgetID(
# streamlit.errors.DuplicateWidgetID: There are multiple widgets with the same `key=''`.
#
# To fix this, please make sure that the `key` argument is unique for each
# widget you create.
# INFO:     127.0.0.1:60160 - "POST /llm_model/get_model_config HTTP/1.1" 200 OK
# 2024-03-22 03:57:17,014 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/get_model_config "HTTP/1.1 200 OK"
# 2024-03-22 03:57:17,372 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:60164 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 03:57:17,375 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# 2024-03-22 03:57:17,465 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:60164 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 03:57:17,468 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:60164 - "POST /llm_model/list_config_models HTTP/1.1" 200 OK
# 2024-03-22 03:57:17,483 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_config_models "HTTP/1.1 200 OK"
# 2024-03-22 03:57:17.501 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 535, in _run_script
#     exec(code, module.__dict__)
#   File "/content/Langchain-Chatchat/webui.py", line 64, in <module>
#     pages[selected_page]["func"](api=api, is_lite=is_lite)
#   File "/content/Langchain-Chatchat/webui_pages/dialogue/dialogue.py", line 275, in dialogue_page
#     chat_box.output_messages()
#   File "/usr/local/lib/python3.10/dist-packages/streamlit_chatbox/messages.py", line 337, in output_messages
#     self.show_feedback(history_index=i, **feedback_kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/streamlit_chatbox/messages.py", line 309, in show_feedback
#     return streamlit_feedback(**kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/streamlit_feedback/__init__.py", line 104, in streamlit_feedback
#     component_value = _component_func(
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/components/v1/components.py", line 80, in __call__
#     return self.create_instance(*args, default=default, key=key, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/metrics_util.py", line 396, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/components/v1/components.py", line 241, in create_instance
#     return_value = marshall_component(dg, element)
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/components/v1/components.py", line 212, in marshall_component
#     component_state = register_widget(
#   File "/usr/local/lib/python3.10/dist-packages/streamlit_option_menu/streamlit_callback.py", line 20, in wrapper_register_widget
#     return register_widget(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/state/widgets.py", line 161, in register_widget
#     return register_widget_from_metadata(metadata, ctx, widget_func_name, element_type)
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/state/widgets.py", line 194, in register_widget_from_metadata
#     raise DuplicateWidgetID(
# streamlit.errors.DuplicateWidgetID: There are multiple widgets with the same `key=''`.
#
# To fix this, please make sure that the `key` argument is unique for each
# widget you create.
# 2024-03-22 03:57:24,571 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:60172 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 03:57:24,573 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# 2024-03-22 03:57:24,733 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:60172 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 03:57:24,735 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:60172 - "POST /llm_model/list_config_models HTTP/1.1" 200 OK
# 2024-03-22 03:57:24,745 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_config_models "HTTP/1.1 200 OK"
# 2024-03-22 03:57:29,374 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:35114 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 03:57:29,380 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# 2024-03-22 03:57:29,584 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:35114 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 03:57:29,587 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:35114 - "POST /llm_model/list_config_models HTTP/1.1" 200 OK
# 2024-03-22 03:57:29,620 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_config_models "HTTP/1.1 200 OK"
# 2024-03-22 03:57:36,678 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:47938 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 03:57:36,680 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# 2024-03-22 03:57:36,737 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:47938 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 03:57:36,739 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:47938 - "POST /llm_model/list_config_models HTTP/1.1" 200 OK
# 2024-03-22 03:57:36,749 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_config_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:47938 - "POST /chat/chat HTTP/1.1" 200 OK
# 2024-03-22 03:57:36,889 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/chat/chat "HTTP/1.1 200 OK"
# 2024-03-22 03:57:36 | INFO | stdout | INFO:     127.0.0.1:58738 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# 2024-03-22 03:57:36,969 - _client.py[line:1758] - INFO: HTTP Request: POST http://127.0.0.1:20000/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-03-22 03:57:36 | INFO | httpx | HTTP Request: POST http://127.0.0.1:20002/worker_generate_stream "HTTP/1.1 200 OK"
# 2024-03-22 03:57:41.051972: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-22 03:57:41.053271: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-22 03:57:41.217053: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-22 03:57:44.263883: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-03-22 04:00:56,070 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:44154 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 04:00:56,073 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# 2024-03-22 04:00:56,231 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:44154 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 04:00:56,234 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:44154 - "POST /llm_model/list_config_models HTTP/1.1" 200 OK
# 2024-03-22 04:00:56,244 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_config_models "HTTP/1.1 200 OK"
# 2024-03-22 04:01:20,617 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:47238 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 04:01:20,620 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# 2024-03-22 04:01:20,781 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:47238 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 04:01:20,784 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:47238 - "POST /llm_model/list_config_models HTTP/1.1" 200 OK
# 2024-03-22 04:01:20,806 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_config_models "HTTP/1.1 200 OK"
# 2024-03-22 04:01:26,800 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:41872 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 04:01:26,802 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# 2024-03-22 04:01:26,860 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:41872 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 04:01:26,862 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:41872 - "POST /llm_model/list_config_models HTTP/1.1" 200 OK
# 2024-03-22 04:01:26,872 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_config_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:41872 - "GET /knowledge_base/list_knowledge_bases HTTP/1.1" 200 OK
# 2024-03-22 04:01:26,882 - _client.py[line:1027] - INFO: HTTP Request: GET http://127.0.0.1:7861/knowledge_base/list_knowledge_bases "HTTP/1.1 200 OK"
# 2024-03-22 04:01:29,978 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:41874 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 04:01:29,980 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# 2024-03-22 04:01:30,037 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:41874 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 04:01:30,040 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:41874 - "POST /llm_model/list_config_models HTTP/1.1" 200 OK
# 2024-03-22 04:01:30,050 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_config_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:41874 - "GET /knowledge_base/list_knowledge_bases HTTP/1.1" 200 OK
# 2024-03-22 04:01:30,059 - _client.py[line:1027] - INFO: HTTP Request: GET http://127.0.0.1:7861/knowledge_base/list_knowledge_bases "HTTP/1.1 200 OK"
# 2024-03-22 04:01:55,867 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:53000 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 04:01:55,869 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# 2024-03-22 04:01:55,926 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:53000 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 04:01:55,928 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:53000 - "POST /llm_model/list_config_models HTTP/1.1" 200 OK
# 2024-03-22 04:01:55,947 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_config_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:53000 - "GET /knowledge_base/list_knowledge_bases HTTP/1.1" 200 OK
# 2024-03-22 04:01:55,956 - _client.py[line:1027] - INFO: HTTP Request: GET http://127.0.0.1:7861/knowledge_base/list_knowledge_bases "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:53000 - "POST /chat/knowledge_base_chat HTTP/1.1" 200 OK
# 2024-03-22 04:01:56,127 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/chat/knowledge_base_chat "HTTP/1.1 200 OK"
# 2024-03-22 04:01:56,129 - SentenceTransformer.py[line:66] - INFO: Load pretrained SentenceTransformer: BAAI/bge-large-zh-v1.5
# Batches: 100% 1/1 [00:00<00:00,  1.18it/s]
# 2024-03-22 04:02:07,101 - faiss_cache.py[line:92] - INFO: loading vector store in 'zhaobiao/vector_store/bge-large-zh-v1.5' from disk.
# 2024-03-22 04:02:07,108 - loader.py[line:54] - INFO: Loading faiss with AVX2 support.
# 2024-03-22 04:02:07,208 - loader.py[line:56] - INFO: Successfully loaded faiss with AVX2 support.
# /usr/local/lib/python3.10/dist-packages/langchain_community/vectorstores/faiss.py:121: UserWarning: Normalizing L2 is not applicable for metric type: METRIC_INNER_PRODUCT
#   warnings.warn(
# 2024-03-22 04:02:07 | INFO | stdout | INFO:     127.0.0.1:39898 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# 2024-03-22 04:02:07,366 - _client.py[line:1758] - INFO: HTTP Request: POST http://127.0.0.1:20000/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-03-22 04:02:07 | INFO | httpx | HTTP Request: POST http://127.0.0.1:20002/worker_generate_stream "HTTP/1.1 200 OK"
# 2024-03-22 04:02:39,135 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:56570 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 04:02:39,138 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# 2024-03-22 04:02:39,196 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:56570 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 04:02:39,198 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:56570 - "POST /llm_model/list_config_models HTTP/1.1" 200 OK
# 2024-03-22 04:02:39,213 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_config_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:56570 - "GET /knowledge_base/list_knowledge_bases HTTP/1.1" 200 OK
# 2024-03-22 04:02:39,224 - _client.py[line:1027] - INFO: HTTP Request: GET http://127.0.0.1:7861/knowledge_base/list_knowledge_bases "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:56570 - "POST /chat/knowledge_base_chat HTTP/1.1" 200 OK
# 2024-03-22 04:02:39,458 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/chat/knowledge_base_chat "HTTP/1.1 200 OK"
# Batches: 100% 1/1 [00:00<00:00, 45.49it/s]
# 2024-03-22 04:02:39 | INFO | stdout | INFO:     127.0.0.1:55634 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# 2024-03-22 04:02:39,569 - _client.py[line:1758] - INFO: HTTP Request: POST http://127.0.0.1:20000/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-03-22 04:02:39 | INFO | httpx | HTTP Request: POST http://127.0.0.1:20002/worker_generate_stream "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:56570 - "POST /llm_model/get_model_config HTTP/1.1" 200 OK
# 2024-03-22 04:02:45,716 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/get_model_config "HTTP/1.1 200 OK"
# 2024-03-22 04:02:45,902 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:37232 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 04:02:45,904 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# 2024-03-22 04:02:45,965 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:37232 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 04:02:45,968 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:37232 - "POST /llm_model/list_config_models HTTP/1.1" 200 OK
# 2024-03-22 04:02:45,980 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_config_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:37232 - "GET /knowledge_base/list_knowledge_bases HTTP/1.1" 200 OK
# 2024-03-22 04:02:45,989 - _client.py[line:1027] - INFO: HTTP Request: GET http://127.0.0.1:7861/knowledge_base/list_knowledge_bases "HTTP/1.1 200 OK"
# 2024-03-22 04:02:52,155 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:37238 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 04:02:52,158 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# 2024-03-22 04:02:52,214 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:37238 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 04:02:52,217 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:37238 - "POST /llm_model/list_config_models HTTP/1.1" 200 OK
# 2024-03-22 04:02:52,226 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_config_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:37238 - "GET /knowledge_base/list_knowledge_bases HTTP/1.1" 200 OK
# 2024-03-22 04:02:52,236 - _client.py[line:1027] - INFO: HTTP Request: GET http://127.0.0.1:7861/knowledge_base/list_knowledge_bases "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:37238 - "POST /chat/knowledge_base_chat HTTP/1.1" 200 OK
# 2024-03-22 04:02:52,520 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/chat/knowledge_base_chat "HTTP/1.1 200 OK"
# Batches: 100% 1/1 [00:00<00:00, 49.49it/s]
# 2024-03-22 04:02:52 | INFO | stdout | INFO:     127.0.0.1:34340 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# 2024-03-22 04:02:52,627 - _client.py[line:1758] - INFO: HTTP Request: POST http://127.0.0.1:20000/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-03-22 04:02:52 | INFO | httpx | HTTP Request: POST http://127.0.0.1:21006/worker_generate_stream "HTTP/1.1 200 OK"
# 2024-03-22 04:02:52,633 - utils.py[line:38] - ERROR: object of type 'NoneType' has no len()
# Traceback (most recent call last):
#   File "/content/Langchain-Chatchat/server/utils.py", line 36, in wrap_done
#     await fn
#   File "/usr/local/lib/python3.10/dist-packages/langchain/chains/base.py", line 385, in acall
#     raise e
#   File "/usr/local/lib/python3.10/dist-packages/langchain/chains/base.py", line 379, in acall
#     await self._acall(inputs, run_manager=run_manager)
#   File "/usr/local/lib/python3.10/dist-packages/langchain/chains/llm.py", line 275, in _acall
#     response = await self.agenerate([inputs], run_manager=run_manager)
#   File "/usr/local/lib/python3.10/dist-packages/langchain/chains/llm.py", line 142, in agenerate
#     return await self.llm.agenerate_prompt(
#   File "/usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py", line 554, in agenerate_prompt
#     return await self.agenerate(
#   File "/usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py", line 514, in agenerate
#     raise exceptions[0]
#   File "/usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py", line 617, in _agenerate_with_cache
#     return await self._agenerate(
#   File "/usr/local/lib/python3.10/dist-packages/langchain_community/chat_models/openai.py", line 522, in _agenerate
#     return await agenerate_from_stream(stream_iter)
#   File "/usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py", line 87, in agenerate_from_stream
#     async for chunk in stream:
#   File "/usr/local/lib/python3.10/dist-packages/langchain_community/chat_models/openai.py", line 493, in _astream
#     if len(chunk["choices"]) == 0:
# TypeError: object of type 'NoneType' has no len()
# 2024-03-22 04:02:52,633 - utils.py[line:40] - ERROR: TypeError: Caught exception: object of type 'NoneType' has no len()
# 2024-03-22 04:03:15,294 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:50302 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 04:03:15,297 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# 2024-03-22 04:03:15,363 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:50302 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 04:03:15,365 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:50302 - "POST /llm_model/list_config_models HTTP/1.1" 200 OK
# 2024-03-22 04:03:15,376 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_config_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:50302 - "GET /knowledge_base/list_knowledge_bases HTTP/1.1" 200 OK
# 2024-03-22 04:03:15,386 - _client.py[line:1027] - INFO: HTTP Request: GET http://127.0.0.1:7861/knowledge_base/list_knowledge_bases "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:50302 - "POST /chat/knowledge_base_chat HTTP/1.1" 200 OK
# 2024-03-22 04:03:15,723 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/chat/knowledge_base_chat "HTTP/1.1 200 OK"
# Batches: 100% 1/1 [00:00<00:00, 10.95it/s]
# 2024-03-22 04:03:15 | INFO | stdout | INFO:     127.0.0.1:45768 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# 2024-03-22 04:03:15,919 - _client.py[line:1758] - INFO: HTTP Request: POST http://127.0.0.1:20000/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-03-22 04:03:15 | INFO | httpx | HTTP Request: POST http://127.0.0.1:21006/worker_generate_stream "HTTP/1.1 200 OK"
# 2024-03-22 04:03:15,930 - utils.py[line:38] - ERROR: object of type 'NoneType' has no len()
# Traceback (most recent call last):
#   File "/content/Langchain-Chatchat/server/utils.py", line 36, in wrap_done
#     await fn
#   File "/usr/local/lib/python3.10/dist-packages/langchain/chains/base.py", line 385, in acall
#     raise e
#   File "/usr/local/lib/python3.10/dist-packages/langchain/chains/base.py", line 379, in acall
#     await self._acall(inputs, run_manager=run_manager)
#   File "/usr/local/lib/python3.10/dist-packages/langchain/chains/llm.py", line 275, in _acall
#     response = await self.agenerate([inputs], run_manager=run_manager)
#   File "/usr/local/lib/python3.10/dist-packages/langchain/chains/llm.py", line 142, in agenerate
#     return await self.llm.agenerate_prompt(
#   File "/usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py", line 554, in agenerate_prompt
#     return await self.agenerate(
#   File "/usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py", line 514, in agenerate
#     raise exceptions[0]
#   File "/usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py", line 617, in _agenerate_with_cache
#     return await self._agenerate(
#   File "/usr/local/lib/python3.10/dist-packages/langchain_community/chat_models/openai.py", line 522, in _agenerate
#     return await agenerate_from_stream(stream_iter)
#   File "/usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py", line 87, in agenerate_from_stream
#     async for chunk in stream:
#   File "/usr/local/lib/python3.10/dist-packages/langchain_community/chat_models/openai.py", line 493, in _astream
#     if len(chunk["choices"]) == 0:
# TypeError: object of type 'NoneType' has no len()
# 2024-03-22 04:03:15,930 - utils.py[line:40] - ERROR: TypeError: Caught exception: object of type 'NoneType' has no len()
# 2024-03-22 04:03:34,854 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:54102 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 04:03:34,857 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# 2024-03-22 04:03:34,957 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:54102 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 04:03:34,961 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:54102 - "POST /llm_model/list_config_models HTTP/1.1" 200 OK
# 2024-03-22 04:03:34,986 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_config_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:54102 - "GET /knowledge_base/list_knowledge_bases HTTP/1.1" 200 OK
# 2024-03-22 04:03:35,003 - _client.py[line:1027] - INFO: HTTP Request: GET http://127.0.0.1:7861/knowledge_base/list_knowledge_bases "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:54102 - "POST /chat/knowledge_base_chat HTTP/1.1" 200 OK
# 2024-03-22 04:03:35,475 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/chat/knowledge_base_chat "HTTP/1.1 200 OK"
# Batches: 100% 1/1 [00:00<00:00, 29.38it/s]
# 2024-03-22 04:03:35 | INFO | stdout | INFO:     127.0.0.1:52120 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# 2024-03-22 04:03:35,664 - _client.py[line:1758] - INFO: HTTP Request: POST http://127.0.0.1:20000/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-03-22 04:03:35 | INFO | httpx | HTTP Request: POST http://127.0.0.1:21006/worker_generate_stream "HTTP/1.1 200 OK"
# 2024-03-22 04:03:35,674 - utils.py[line:38] - ERROR: object of type 'NoneType' has no len()
# Traceback (most recent call last):
#   File "/content/Langchain-Chatchat/server/utils.py", line 36, in wrap_done
#     await fn
#   File "/usr/local/lib/python3.10/dist-packages/langchain/chains/base.py", line 385, in acall
#     raise e
#   File "/usr/local/lib/python3.10/dist-packages/langchain/chains/base.py", line 379, in acall
#     await self._acall(inputs, run_manager=run_manager)
#   File "/usr/local/lib/python3.10/dist-packages/langchain/chains/llm.py", line 275, in _acall
#     response = await self.agenerate([inputs], run_manager=run_manager)
#   File "/usr/local/lib/python3.10/dist-packages/langchain/chains/llm.py", line 142, in agenerate
#     return await self.llm.agenerate_prompt(
#   File "/usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py", line 554, in agenerate_prompt
#     return await self.agenerate(
#   File "/usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py", line 514, in agenerate
#     raise exceptions[0]
#   File "/usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py", line 617, in _agenerate_with_cache
#     return await self._agenerate(
#   File "/usr/local/lib/python3.10/dist-packages/langchain_community/chat_models/openai.py", line 522, in _agenerate
#     return await agenerate_from_stream(stream_iter)
#   File "/usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py", line 87, in agenerate_from_stream
#     async for chunk in stream:
#   File "/usr/local/lib/python3.10/dist-packages/langchain_community/chat_models/openai.py", line 493, in _astream
#     if len(chunk["choices"]) == 0:
# TypeError: object of type 'NoneType' has no len()
# 2024-03-22 04:03:35,675 - utils.py[line:40] - ERROR: TypeError: Caught exception: object of type 'NoneType' has no len()
# 2024-03-22 04:22:42,134 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:59324 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 04:22:42,137 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# 2024-03-22 04:22:42,193 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:59324 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 04:22:42,195 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:59324 - "POST /llm_model/list_config_models HTTP/1.1" 200 OK
# 2024-03-22 04:22:42,208 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_config_models "HTTP/1.1 200 OK"
# 2024-03-22 04:31:28,150 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:35194 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 04:31:28,153 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# 2024-03-22 04:31:28,208 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:35194 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 04:31:28,210 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:35194 - "POST /llm_model/list_config_models HTTP/1.1" 200 OK
# 2024-03-22 04:31:28,221 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_config_models "HTTP/1.1 200 OK"
# 2024-03-22 04:34:19,959 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:55224 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 04:34:19,962 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# 2024-03-22 04:34:20,017 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:55224 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 04:34:20,019 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:55224 - "POST /llm_model/list_config_models HTTP/1.1" 200 OK
# 2024-03-22 04:34:20,031 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_config_models "HTTP/1.1 200 OK"
# 2024-03-22 04:38:10,815 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:54772 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 04:38:10,818 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# 2024-03-22 04:38:10,874 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:54772 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 04:38:10,876 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:54772 - "POST /llm_model/list_config_models HTTP/1.1" 200 OK
# 2024-03-22 04:38:10,895 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_config_models "HTTP/1.1 200 OK"
# 2024-03-22 04:44:33,920 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:60162 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 04:44:33,923 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# 2024-03-22 04:44:33,980 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:60162 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 04:44:33,982 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:60162 - "POST /llm_model/list_config_models HTTP/1.1" 200 OK
# 2024-03-22 04:44:33,992 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_config_models "HTTP/1.1 200 OK"
# 2024-03-22 05:13:26,061 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:40158 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 05:13:26,064 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# 2024-03-22 05:13:26,121 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:40158 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 05:13:26,123 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:40158 - "POST /llm_model/list_config_models HTTP/1.1" 200 OK
# 2024-03-22 05:13:26,133 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_config_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:40158 - "GET /knowledge_base/list_knowledge_bases HTTP/1.1" 200 OK
# 2024-03-22 05:13:26,142 - _client.py[line:1027] - INFO: HTTP Request: GET http://127.0.0.1:7861/knowledge_base/list_knowledge_bases "HTTP/1.1 200 OK"
# 2024-03-22 05:13:29,547 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:40168 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 05:13:29,549 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# 2024-03-22 05:13:29,605 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:40168 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 05:13:29,607 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:40168 - "POST /llm_model/list_config_models HTTP/1.1" 200 OK
# 2024-03-22 05:13:29,626 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_config_models "HTTP/1.1 200 OK"
# 2024-03-22 05:31:39,226 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:44902 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 05:31:39,229 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# 2024-03-22 05:31:39,288 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:20001/list_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:44902 - "POST /llm_model/list_running_models HTTP/1.1" 200 OK
# 2024-03-22 05:31:39,291 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_running_models "HTTP/1.1 200 OK"
# INFO:     127.0.0.1:44902 - "POST /llm_model/list_config_models HTTP/1.1" 200 OK
# 2024-03-22 05:31:39,301 - _client.py[line:1027] - INFO: HTTP Request: POST http://127.0.0.1:7861/llm_model/list_config_models "HTTP/1.1 200 OK"
